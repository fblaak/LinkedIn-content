# %%
from pathlib import Path
import data_profiler

base_path = Path.cwd()
data_path = base_path / "data"

profile = data_profiler.profile_folder(
    folder_path=data_path
)

profile
# Out:
#   table_name  column_name data_type                              examples  \
# 0  customers  customer_id     int64              [200001, 200002, 200003]
# 1  customers      type_cd    object                             [B, A, X]
# 2  customers          age     int64                          [70, 45, 40]
# 3  customers   created_at    object  [30/05/2025, 12/04/2024, 04/02/2025]
# 4  customers     end_date    object  [04/02/2027, 21/11/2024, 24/11/2026]
# 5     orders     order_id     int64           [9000001, 9000002, 9000003]
# 6     orders      cust_no     int64              [208363, 202719, 209433]
# 7     orders   product_cd    object                 [P1004, P1003, P1006]
# 8     orders   amount_eur   float64                [82.73, 132.79, 30.73]
#
#    row_#  empty_#  empty_%  unique_#  unique_%  is_unique        min  \
# 0  11925        0     0.00     11885     99.66      False   200001.0
# 1  11925        0     0.00         4      0.03      False        NaN
# ...
